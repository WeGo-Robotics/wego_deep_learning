# %% [markdown]
# # **LIMO Pro Object Detection YOLO11 Mobel Training**
# 1. Connect to drive
# 2. Extract dataset
# 3. Import Modules
# 4. Create Yaml
# 5. Train & Save

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip /content/drive/MyDrive/dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/dl_images/221_221_625_20250526025602.jpg
#   inflating: dataset/dl_images/221_221_626_20250526025602.jpg
#   inflating: dataset/dl_images/221_221_630_20250526025603.jpg
#   inflating: dataset/dl_images/221_221_633_20250526025604.jpg
#   inflating: dataset/dl_images/221_221_634_20250526025604.jpg
#   inflating: dataset/dl_images/221_221_637_20250526025605.jpg
#   inflating: dataset/dl_images/221_221_639_20250526025605.jpg
#   inflating: dataset/dl_images/221_221_643_20250526025606.jpg
#   inflating: dataset/dl_images/221_221_645_20250526025607.jpg
#   inflating: dataset/dl_images/221_221_647_20250526025607.jpg
#   inflating: dataset/dl_images/221_221_649_20250526025608.jpg
#   inflating: dataset/dl_images/221_221_650_20250526025608.jpg
#   inflating: dataset/dl_images/221_221_653_20250526025609.jpg
#   inflating: dataset/dl_images/221_221_654_20250526025609.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.2 MB/s eta 0:00:00
# ...

# %%
# %%writefile /content/coco8.yaml
# path: /content/dataset/yolo_images
# train: images/train
# val: images/val
# test:
#
# nc: 7
# names:
#   - speed_up
#   - slow_down
#   - turn_right
#   - red_light
#   - yellow_light
#   - green_light
#   - pedestrian
# Out:
# Writing /content/coco8.yaml

# %%
# !yolo train model=yolo11n.pt data=/content/coco8.yaml epochs=200 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.175 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
